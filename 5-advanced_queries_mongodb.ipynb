# %% [markdown]
# # Querrying a noSQL db (MongoDB)

# %% [markdown]
# MongoDB supports both basic and advanced CRUD operations (**C**reate **R**ead **U**pdate and **D**elete).
#
# In this notebook, we'll explore the **Read** operations - specifically, how to query an existing collection of documents in MongoDB.
#
# >NOTE: For more information on MongoDB's support for query operations, see [here]( https://docs.mongodb.com/manual/tutorial/query-documents/.).

# %% [markdown]
# ## Step 1: Establish a connection to the Database
#
# You will need to setup the client so that it connects to your project.
#
# Then, you'll need to specify the database within this project.
#
# Finally, you'll need to specify the collection within which you wish to make the query.

# %%
import pymongo # pymongo is a python driver for MongoDB

client = pymongo.MongoClient('mongodb://localhost:27017/')

db = client.cardio # # this is a database that was created in a previous notebook (4)
collection = db.patients # this is a collection that was created in a previous notebook (4)

# %% [markdown]
# ## Step2: Query the collection
#
# You can use many different approaches to querrying the collection.

# %% [markdown]
# ### Get all documents in a collection

# %%
import json  
query = {} # select all documents (same as select * from patients)
doc = collection.find(query)
for record in doc: # 'doc' is a cursor that we can iterate over
    print(record)
# Out:
# {'_id': 1, 'office_num': [3], 'patient_info': {'fname': 'Jordan', 'lname': 'Smith', 'mname': 'Jane'}, 'patient_numbers': ['177-763-1706', '690-743-9150', '008-063-6083'], 'weights': [343, 373, 209, 266], 'height': 129, 'bp_readings': [{'Systolic': 148, 'Diastolic': 84, 'Rate': 78}, {'Systolic': 101, 'Diastolic': 83, 'Rate': 95}, {'Systolic': 141, 'Diastolic': 73, 'Rate': 71}, {'Systolic': 140, 'Diastolic': 93, 'Rate': 78}, {'Systolic': 107, 'Diastolic': 93, 'Rate': 81}], 'comments': 'good patient', 'readings': [{'Systolic': 999, 'Diastolic': 999, 'Rate': 999}]}
# {'_id': 2, 'office_num': [9], 'patient_info': {'fname': 'Susan', 'lname': 'Granger'}, 'patient_numbers': ['497-869-0736', '625-851-7812', '865-707-0499'], 'weights': [291, 177, 176, 347, 206], 'height': 101, 'bp_readings': [{'Systolic': 134, 'Diastolic': 99, 'Rate': 95}, {'Systolic': 114, 'Diastolic': 82, 'Rate': 92}, {'Systolic': 122, 'Diastolic': 97, 'Rate': 96}, {'Systolic': 122, 'Diastolic': 84, 'Rate': 77}, {'Systolic': 142, 'Diastolic': 87, 'Rate': 98}]}
# {'_id': 3, 'office_num': [7], 'patient_info': {'fname': 'Tom', 'lname': 'Hale'}, 'patient_numbers': ['883-607-5983', '867-565-0889'], 'weights': [259, 324, 397, 104, 207], 'height': 181, 'bp_readings': [{'Systolic': 135, 'Diastolic': 88, 'Rate': 71}, {'Systolic': 105, 'Diastolic': 95, 'Rate': 95}, {'Systolic': 116, 'Diastolic': 71, 'Rate': 103}, {'Systolic': 104, 'Diastolic': 72, 'Rate': 61}]}
# {'_id': 4, 'office_num': [1], 'patient_info': {'fname': 'Tom', 'lname': ' Fox'}, 'patient_numbers': ['419-254-1224', '824-475-7710'], 'weights': [287, 265, 305], 'height': 124, 'bp_readings': [{'Systolic': 106, 'Diastolic': 78, 'Rate': 106}, {'Systolic': 132, 'Diastolic': 76, 'Rate': 98}, {'Systolic': 127, 'Diastolic': 96, 'Rate': 61}, {'Systolic': 114, 'Diastolic': 70, 'Rate': 85}, {'Systolic': 109, 'Diastolic': 71, 'Rate': 106}, {'Systolic': 110, 'Diastolic': 84, 'Rate': 105}]}
# {'_id': 5, 'office_num': [9], 'patient_info': {'fname': 'James', 'lname': 'Hale'}, 'patient_numbers': ['380-695-6042', '304-114-4269', '420-809-3972'], 'weights': [350, 109, 283, 192, 267], 'height': 112, 'bp_readings': [{'Systolic': 136, 'Diastolic': 91, 'Rate': 87}, {'Systolic': 137, 'Diastolic': 76, 'Rate': 91}, {'Systolic': 106, 'Diastolic': 91, 'Rate': 84}, {'Systolic': 118, 'Diastolic': 86, 'Rate': 91}, {'Systolic': 101, 'Diastolic': 80, 'Rate': 99}]}
# {'_id': 6, 'office_num': [5], 'patient_info': {'fname': 'John', 'lname': 'Carmichael'}, 'patient_numbers': ['592-563-4168', '587-831-0122'], 'weights': [365, 199], 'height': 134, 'bp_readings': [{'Systolic': 138, 'Diastolic': 86, 'Rate': 76}, {'Systolic': 123, 'Diastolic': 80, 'Rate': 81}, {'Systolic': 107, 'Diastolic': 79, 'Rate': 75}, {'Systolic': 138, 'Diastolic': 94, 'Rate': 105}, {'Systolic': 131, 'Diastolic': 74, 'Rate': 97}, {'Systolic': 135, 'Diastolic': 94, 'Rate': 66}, {'Systolic': 120, 'Diastolic': 71, 'Rate': 86}]}
# {'_id': 7, 'office_num': [7], 'patient_info': {'fname': 'Tom', 'lname': 'Carmichael'}, 'patient_numbers': ['519-961-9839', '145-498-1741'], 'weights': [241], 'height': 101, 'bp_readings': [{'Systolic': 105, 'Diastolic': 83, 'Rate': 67}, {'Systolic': 150, 'Diastolic': 71, 'Rate': 72}]}
# {'_id': 8, 'office_num': [10], 'patient_info': {'fname': 'Liam', 'lname': 'Carmichael'}, 'patient_numbers': ['723-216-6848', '475-135-0004'], 'weights': [253, 320, 290, 250, 294], 'height': 108, 'bp_readings': [{'Systolic': 120, 'Diastolic': 89, 'Rate': 89}, {'Systolic': 107, 'Diastolic': 78, 'Rate': 73}, {'Systolic': 150, 'Diastolic': 89, 'Rate': 109}]}
# {'_id': 9, 'office_num': [6], 'patient_info': {'fname': 'Richard', 'lname': 'Carmichael'}, 'patient_numbers': ['343-351-4171', '953-640-5259', '435-189-9913', '303-614-8110'], 'weights': [238], 'height': 196, 'bp_readings': [{'Systolic': 131, 'Diastolic': 85, 'Rate': 69}, {'Systolic': 106, 'Diastolic': 86, 'Rate': 109}, {'Systolic': 150, 'Diastolic': 80, 'Rate': 64}, {'Systolic': 132, 'Diastolic': 91, 'Rate': 71}, {'Systolic': 111, 'Diastolic': 94, 'Rate': 69}, {'Systolic': 109, 'Diastolic': 96, 'Rate': 80}, {'Systolic': 119, 'Diastolic': 73, 'Rate': 105}]}
# {'_id': 10, 'office_num': [3], 'patient_info': {'fname': 'James', 'lname': 'Carmichael'}, 'patient_numbers': ['059-832-4682', '034-176-8487', '870-652-4706', '900-592-9224'], 'weights': [293, 378, 295], 'height': 122, 'bp_readings': [{'Systolic': 114, 'Diastolic': 85, 'Rate': 60}, {'Systolic': 111, 'Diastolic': 86, 'Rate': 80}, {'Systolic': 132, 'Diastolic': 98, 'Rate': 101}]}
# {'_id': 11, 'office_num': [4], 'patient_info': {'fname': 'James', 'lname': 'Madden'}, 'patient_numbers': ['736-589-4301', '852-834-4485', '279-119-8962'], 'weights': [218, 308], 'height': 127, 'bp_readings': [{'Systolic': 131, 'Diastolic': 91, 'Rate': 85}, {'Systolic': 145, 'Diastolic': 90, 'Rate': 82}]}
# {'_id': 12, 'office_num': [9], 'patient_info': {'fname': 'July', 'lname': 'Hale'}, 'patient_numbers': ['081-414-1291', '736-662-5729', '731-698-6144', '368-038-7900'], 'weights': [214, 223, 195, 178, 235], 'height': 118, 'bp_readings': [{'Systolic': 112, 'Diastolic': 78, 'Rate': 79}, {'Systolic': 137, 'Diastolic': 94, 'Rate': 76}, {'Systolic': 143, 'Diastolic': 84, 'Rate': 110}, {'Systolic': 110, 'Diastolic': 87, 'Rate': 82}, {'Systolic': 131, 'Diastolic': 83, 'Rate': 67}, {'Systolic': 149, 'Diastolic': 76, 'Rate': 96}, {'Systolic': 124, 'Diastolic': 76, 'Rate': 78}, {'Systolic': 106, 'Diastolic': 98, 'Rate': 61}, {'Systolic': 107, 'Diastolic': 88, 'Rate': 107}, {'Systolic': 100, 'Diastolic': 87, 'Rate': 78}]}
# {'_id': 13, 'office_num': [2], 'patient_info': {'fname': 'Jerry', 'lname': 'Madden'}, 'patient_numbers': ['468-585-0177', '548-659-7166', '380-498-3798', '642-798-3580'], 'weights': [386, 308, 297, 262], 'height': 179, 'bp_readings': [{'Systolic': 131, 'Diastolic': 93, 'Rate': 75}, {'Systolic': 140, 'Diastolic': 90, 'Rate': 78}, {'Systolic': 140, 'Diastolic': 70, 'Rate': 86}]}
# {'_id': 14, 'office_num': [7], 'patient_info': {'fname': 'Tom', 'lname': ' Fox'}, 'patient_numbers': ['190-546-8427', '472-780-4819'], 'weights': [125, 271, 124, 316], 'height': 102, 'bp_readings': [{'Systolic': 132, 'Diastolic': 92, 'Rate': 70}, {'Systolic': 144, 'Diastolic': 72, 'Rate': 85}, {'Systolic': 140, 'Diastolic': 92, 'Rate': 77}, {'Systolic': 138, 'Diastolic': 79, 'Rate': 73}]}
# {'_id': 15, 'office_num': [4], 'patient_info': {'fname': 'Ethan', 'lname': ' Fox'}, 'patient_numbers': ['185-788-0248', '459-368-6274'], 'weights': [258, 203, 222, 215, 105], 'height': 179, 'bp_readings': [{'Systolic': 120, 'Diastolic': 99, 'Rate': 87}, {'Systolic': 148, 'Diastolic': 77, 'Rate': 110}, {'Systolic': 117, 'Diastolic': 76, 'Rate': 64}, {'Systolic': 140, 'Diastolic': 93, 'Rate': 70}, {'Systolic': 137, 'Diastolic': 84, 'Rate': 97}, {'Systolic': 146, 'Diastolic': 74, 'Rate': 98}, {'Systolic': 116, 'Diastolic': 84, 'Rate': 93}, {'Systolic': 110, 'Diastolic': 74, 'Rate': 109}]}
# {'_id': 16, 'office_num': [8], 'patient_info': {'fname': 'Ethan', 'lname': ' Fox'}, 'patient_numbers': ['313-411-3657', '120-090-3078', '975-419-2136'], 'weights': [343, 320], 'height': 148, 'bp_readings': [{'Systolic': 114, 'Diastolic': 77, 'Rate': 78}, {'Systolic': 129, 'Diastolic': 87, 'Rate': 97}, {'Systolic': 124, 'Diastolic': 76, 'Rate': 88}, {'Systolic': 145, 'Diastolic': 78, 'Rate': 81}]}
# {'_id': 17, 'office_num': [10], 'patient_info': {'fname': 'Betty', 'lname': 'Granger'}, 'patient_numbers': ['000-756-9436', '220-062-8096'], 'weights': [156, 130, 326], 'height': 183, 'bp_readings': [{'Systolic': 100, 'Diastolic': 71, 'Rate': 94}, {'Systolic': 103, 'Diastolic': 86, 'Rate': 68}, {'Systolic': 102, 'Diastolic': 99, 'Rate': 77}, {'Systolic': 149, 'Diastolic': 73, 'Rate': 87}, {'Systolic': 105, 'Diastolic': 76, 'Rate': 61}, {'Systolic': 131, 'Diastolic': 90, 'Rate': 68}]}
# {'_id': 18, 'office_num': [4], 'patient_info': {'fname': 'Susan', 'lname': 'Boone'}, 'patient_numbers': ['544-330-9925', '698-805-8683', '861-491-4212'], 'weights': [194], 'height': 154, 'bp_readings': [{'Systolic': 103, 'Diastolic': 90, 'Rate': 65}, {'Systolic': 132, 'Diastolic': 85, 'Rate': 92}]}
# {'_id': 19, 'office_num': [2], 'patient_info': {'fname': 'Ethan', 'lname': 'Jones'}, 'patient_numbers': ['807-267-0841', '451-406-0452'], 'weights': [284, 149, 245], 'height': 112, 'bp_readings': [{'Systolic': 115, 'Diastolic': 86, 'Rate': 95}, {'Systolic': 113, 'Diastolic': 80, 'Rate': 81}, {'Systolic': 132, 'Diastolic': 95, 'Rate': 85}, {'Systolic': 137, 'Diastolic': 85, 'Rate': 66}, {'Systolic': 108, 'Diastolic': 90, 'Rate': 88}, {'Systolic': 133, 'Diastolic': 87, 'Rate': 106}, {'Systolic': 137, 'Diastolic': 92, 'Rate': 93}, {'Systolic': 134, 'Diastolic': 70, 'Rate': 78}]}
# {'_id': 20, 'office_num': [4], 'patient_info': {'fname': 'Ethan', 'lname': 'Hart'}, 'patient_numbers': ['516-529-1048', '564-554-5880', '812-555-9174', '775-619-0208'], 'weights': [384, 218, 215, 383], 'height': 195, 'bp_readings': [{'Systolic': 123, 'Diastolic': 95, 'Rate': 101}, {'Systolic': 123, 'Diastolic': 82, 'Rate': 79}, {'Systolic': 129, 'Diastolic': 89, 'Rate': 81}, {'Systolic': 134, 'Diastolic': 86, 'Rate': 70}, {'Systolic': 101, 'Diastolic': 74, 'Rate': 76}, {'Systolic': 143, 'Diastolic': 77, 'Rate': 96}, {'Systolic': 108, 'Diastolic': 99, 'Rate': 67}]}
# {'_id': 21, 'office_num': [7], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Langston'}, 'patient_numbers': ['184-134-1981', '132-860-9574'], 'weights': [192, 396], 'height': 163, 'bp_readings': [{'Systolic': 127, 'Diastolic': 84, 'Rate': 103}, {'Systolic': 123, 'Diastolic': 87, 'Rate': 72}, {'Systolic': 130, 'Diastolic': 93, 'Rate': 64}, {'Systolic': 116, 'Diastolic': 83, 'Rate': 72}, {'Systolic': 100, 'Diastolic': 93, 'Rate': 94}]}
# {'_id': 22, 'office_num': [9], 'patient_info': {'fname': 'Jack', 'lname': 'Smith'}, 'patient_numbers': ['989-960-5703', '408-148-5898', '486-886-9947'], 'weights': [157, 349, 317], 'height': 175, 'bp_readings': [{'Systolic': 135, 'Diastolic': 94, 'Rate': 70}, {'Systolic': 116, 'Diastolic': 90, 'Rate': 60}, {'Systolic': 127, 'Diastolic': 93, 'Rate': 102}, {'Systolic': 136, 'Diastolic': 71, 'Rate': 83}]}
# {'_id': 23, 'office_num': [7], 'patient_info': {'fname': 'Richard', 'lname': 'Jones'}, 'patient_numbers': ['106-474-5756', '717-526-2024'], 'weights': [155, 391, 237], 'height': 152, 'bp_readings': [{'Systolic': 132, 'Diastolic': 79, 'Rate': 107}, {'Systolic': 126, 'Diastolic': 92, 'Rate': 77}, {'Systolic': 127, 'Diastolic': 80, 'Rate': 109}, {'Systolic': 131, 'Diastolic': 76, 'Rate': 105}, {'Systolic': 131, 'Diastolic': 82, 'Rate': 105}, {'Systolic': 127, 'Diastolic': 72, 'Rate': 64}]}
# {'_id': 24, 'office_num': [4], 'patient_info': {'fname': 'July', 'lname': 'Granger'}, 'patient_numbers': ['014-271-6201', '690-838-6501', '861-442-7031', '617-487-6197'], 'weights': [166], 'height': 149, 'bp_readings': [{'Systolic': 110, 'Diastolic': 86, 'Rate': 76}, {'Systolic': 126, 'Diastolic': 93, 'Rate': 94}, {'Systolic': 118, 'Diastolic': 97, 'Rate': 91}, {'Systolic': 140, 'Diastolic': 98, 'Rate': 94}, {'Systolic': 113, 'Diastolic': 95, 'Rate': 108}]}
# {'_id': 25, 'office_num': [8], 'patient_info': {'fname': 'Betty', 'lname': 'Jones'}, 'patient_numbers': ['540-874-1384', '436-224-3689', '089-826-4474', '473-759-7352'], 'weights': [182, 387, 320, 363, 166], 'height': 107, 'bp_readings': [{'Systolic': 120, 'Diastolic': 86, 'Rate': 104}, {'Systolic': 108, 'Diastolic': 90, 'Rate': 108}, {'Systolic': 113, 'Diastolic': 80, 'Rate': 99}, {'Systolic': 131, 'Diastolic': 85, 'Rate': 81}, {'Systolic': 107, 'Diastolic': 74, 'Rate': 68}, {'Systolic': 144, 'Diastolic': 78, 'Rate': 74}, {'Systolic': 105, 'Diastolic': 90, 'Rate': 94}, {'Systolic': 144, 'Diastolic': 71, 'Rate': 96}, {'Systolic': 111, 'Diastolic': 91, 'Rate': 67}, {'Systolic': 114, 'Diastolic': 88, 'Rate': 72}]}
# {'_id': 26, 'office_num': [7], 'patient_info': {'fname': 'Ethan', 'lname': 'Jones'}, 'patient_numbers': ['493-134-5498', '601-552-1429'], 'weights': [267], 'height': 109, 'bp_readings': [{'Systolic': 146, 'Diastolic': 73, 'Rate': 79}, {'Systolic': 120, 'Diastolic': 77, 'Rate': 77}, {'Systolic': 133, 'Diastolic': 71, 'Rate': 83}]}
# {'_id': 27, 'office_num': [2], 'patient_info': {'fname': 'July', 'lname': 'Hart'}, 'patient_numbers': ['315-408-5152', '946-199-8796', '864-348-2098'], 'weights': [179], 'height': 130, 'bp_readings': [{'Systolic': 127, 'Diastolic': 78, 'Rate': 94}, {'Systolic': 101, 'Diastolic': 78, 'Rate': 94}, {'Systolic': 117, 'Diastolic': 86, 'Rate': 76}, {'Systolic': 130, 'Diastolic': 74, 'Rate': 85}, {'Systolic': 145, 'Diastolic': 73, 'Rate': 107}]}
# {'_id': 28, 'office_num': [2], 'patient_info': {'fname': 'Susan', 'lname': 'Hale'}, 'patient_numbers': ['888-909-4722', '192-375-5422', '676-192-4490'], 'weights': [94, 157, 284, 377, 141], 'height': 158, 'bp_readings': [{'Systolic': 149, 'Diastolic': 83, 'Rate': 98}, {'Systolic': 143, 'Diastolic': 83, 'Rate': 77}]}
# {'_id': 29, 'office_num': [7], 'patient_info': {'fname': 'Liam', 'lname': 'Langston'}, 'patient_numbers': ['017-000-1928', '858-495-7393', '185-210-5654'], 'weights': [312], 'height': 153, 'bp_readings': [{'Systolic': 122, 'Diastolic': 79, 'Rate': 108}, {'Systolic': 121, 'Diastolic': 84, 'Rate': 104}, {'Systolic': 115, 'Diastolic': 90, 'Rate': 99}, {'Systolic': 133, 'Diastolic': 74, 'Rate': 63}, {'Systolic': 121, 'Diastolic': 91, 'Rate': 67}, {'Systolic': 132, 'Diastolic': 75, 'Rate': 94}, {'Systolic': 141, 'Diastolic': 90, 'Rate': 91}, {'Systolic': 121, 'Diastolic': 94, 'Rate': 105}]}
# {'_id': 30, 'office_num': [10], 'patient_info': {'fname': 'John', 'lname': 'Boone'}, 'patient_numbers': ['626-313-5537', '757-367-6819'], 'weights': [226, 154, 166, 96], 'height': 148, 'bp_readings': [{'Systolic': 106, 'Diastolic': 95, 'Rate': 61}, {'Systolic': 141, 'Diastolic': 72, 'Rate': 71}, {'Systolic': 129, 'Diastolic': 94, 'Rate': 84}, {'Systolic': 142, 'Diastolic': 86, 'Rate': 78}, {'Systolic': 109, 'Diastolic': 74, 'Rate': 93}, {'Systolic': 106, 'Diastolic': 78, 'Rate': 61}, {'Systolic': 129, 'Diastolic': 82, 'Rate': 100}, {'Systolic': 145, 'Diastolic': 93, 'Rate': 110}]}
# {'_id': 31, 'office_num': [9], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Hart'}, 'patient_numbers': ['836-225-3188', '226-908-3630'], 'weights': [187, 348, 364, 129, 216], 'height': 150, 'bp_readings': [{'Systolic': 107, 'Diastolic': 88, 'Rate': 101}, {'Systolic': 103, 'Diastolic': 82, 'Rate': 65}, {'Systolic': 135, 'Diastolic': 73, 'Rate': 101}, {'Systolic': 130, 'Diastolic': 71, 'Rate': 93}, {'Systolic': 115, 'Diastolic': 94, 'Rate': 60}, {'Systolic': 101, 'Diastolic': 97, 'Rate': 79}, {'Systolic': 129, 'Diastolic': 78, 'Rate': 106}, {'Systolic': 126, 'Diastolic': 75, 'Rate': 98}, {'Systolic': 108, 'Diastolic': 87, 'Rate': 105}]}
# {'_id': 32, 'office_num': [9], 'patient_info': {'fname': 'Susan', 'lname': 'Boone'}, 'patient_numbers': ['682-663-7452', '494-291-5524', '445-649-7022', '433-198-9386'], 'weights': [385, 161], 'height': 170, 'bp_readings': [{'Systolic': 125, 'Diastolic': 92, 'Rate': 72}, {'Systolic': 105, 'Diastolic': 90, 'Rate': 64}, {'Systolic': 109, 'Diastolic': 95, 'Rate': 102}, {'Systolic': 103, 'Diastolic': 70, 'Rate': 107}, {'Systolic': 125, 'Diastolic': 82, 'Rate': 86}, {'Systolic': 143, 'Diastolic': 74, 'Rate': 97}, {'Systolic': 138, 'Diastolic': 74, 'Rate': 103}, {'Systolic': 134, 'Diastolic': 87, 'Rate': 64}, {'Systolic': 115, 'Diastolic': 97, 'Rate': 84}]}
# {'_id': 33, 'office_num': [5], 'patient_info': {'fname': 'James', 'lname': 'Hart'}, 'patient_numbers': ['234-257-8418', '437-049-9195', '749-005-2211'], 'weights': [390, 215, 196, 348], 'height': 164, 'bp_readings': [{'Systolic': 107, 'Diastolic': 99, 'Rate': 105}, {'Systolic': 113, 'Diastolic': 96, 'Rate': 84}, {'Systolic': 142, 'Diastolic': 99, 'Rate': 93}, {'Systolic': 108, 'Diastolic': 96, 'Rate': 105}, {'Systolic': 137, 'Diastolic': 78, 'Rate': 106}, {'Systolic': 100, 'Diastolic': 92, 'Rate': 67}, {'Systolic': 112, 'Diastolic': 94, 'Rate': 96}, {'Systolic': 124, 'Diastolic': 91, 'Rate': 90}]}
# {'_id': 34, 'office_num': [5], 'patient_info': {'fname': 'John', 'lname': 'Carmichael'}, 'patient_numbers': ['883-646-6471', '228-070-7368', '531-106-7329', '838-685-3359'], 'weights': [264], 'height': 106, 'bp_readings': [{'Systolic': 102, 'Diastolic': 96, 'Rate': 99}, {'Systolic': 111, 'Diastolic': 98, 'Rate': 69}, {'Systolic': 118, 'Diastolic': 85, 'Rate': 62}, {'Systolic': 137, 'Diastolic': 86, 'Rate': 64}, {'Systolic': 136, 'Diastolic': 82, 'Rate': 65}, {'Systolic': 125, 'Diastolic': 95, 'Rate': 92}, {'Systolic': 136, 'Diastolic': 90, 'Rate': 79}, {'Systolic': 125, 'Diastolic': 78, 'Rate': 82}, {'Systolic': 130, 'Diastolic': 99, 'Rate': 63}]}
# {'_id': 35, 'office_num': [1], 'patient_info': {'fname': 'Liam', 'lname': ' Fox'}, 'patient_numbers': ['529-984-1956', '680-991-0980', '155-580-5917', '187-588-0255'], 'weights': [164, 387], 'height': 118, 'bp_readings': [{'Systolic': 125, 'Diastolic': 80, 'Rate': 92}, {'Systolic': 126, 'Diastolic': 96, 'Rate': 83}, {'Systolic': 121, 'Diastolic': 97, 'Rate': 76}]}
# {'_id': 36, 'office_num': [1], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Smith'}, 'patient_numbers': ['346-849-9112', '461-248-4331', '470-843-8185', '548-207-5005'], 'weights': [173, 375, 110, 391], 'height': 189, 'bp_readings': [{'Systolic': 127, 'Diastolic': 75, 'Rate': 72}, {'Systolic': 114, 'Diastolic': 73, 'Rate': 97}, {'Systolic': 108, 'Diastolic': 88, 'Rate': 92}, {'Systolic': 107, 'Diastolic': 93, 'Rate': 77}, {'Systolic': 129, 'Diastolic': 76, 'Rate': 110}, {'Systolic': 103, 'Diastolic': 81, 'Rate': 89}, {'Systolic': 121, 'Diastolic': 99, 'Rate': 99}, {'Systolic': 146, 'Diastolic': 81, 'Rate': 74}, {'Systolic': 140, 'Diastolic': 70, 'Rate': 60}, {'Systolic': 131, 'Diastolic': 71, 'Rate': 70}]}
# {'_id': 37, 'office_num': [9], 'patient_info': {'fname': 'John', 'lname': 'Jones'}, 'patient_numbers': ['182-083-3743', '785-561-3923'], 'weights': [242, 387, 308, 332, 276], 'height': 102, 'bp_readings': [{'Systolic': 101, 'Diastolic': 99, 'Rate': 66}, {'Systolic': 142, 'Diastolic': 90, 'Rate': 96}, {'Systolic': 142, 'Diastolic': 89, 'Rate': 87}, {'Systolic': 145, 'Diastolic': 88, 'Rate': 81}, {'Systolic': 121, 'Diastolic': 72, 'Rate': 101}, {'Systolic': 126, 'Diastolic': 76, 'Rate': 104}, {'Systolic': 132, 'Diastolic': 95, 'Rate': 91}, {'Systolic': 138, 'Diastolic': 88, 'Rate': 102}, {'Systolic': 135, 'Diastolic': 86, 'Rate': 90}]}
# {'_id': 38, 'office_num': [10], 'patient_info': {'fname': 'Jack', 'lname': 'Carmichael'}, 'patient_numbers': ['849-698-4440', '907-753-8737', '526-601-5048'], 'weights': [246], 'height': 148, 'bp_readings': [{'Systolic': 120, 'Diastolic': 80, 'Rate': 79}, {'Systolic': 137, 'Diastolic': 98, 'Rate': 110}]}
# {'_id': 39, 'office_num': [4], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Smith'}, 'patient_numbers': ['112-469-5302', '895-446-6871', '363-909-3336'], 'weights': [197, 167, 243, 274], 'height': 100, 'bp_readings': [{'Systolic': 128, 'Diastolic': 85, 'Rate': 70}, {'Systolic': 143, 'Diastolic': 74, 'Rate': 61}, {'Systolic': 123, 'Diastolic': 83, 'Rate': 95}, {'Systolic': 121, 'Diastolic': 97, 'Rate': 92}, {'Systolic': 131, 'Diastolic': 80, 'Rate': 98}, {'Systolic': 107, 'Diastolic': 88, 'Rate': 101}]}
# {'_id': 40, 'office_num': [9], 'patient_info': {'fname': 'Susan', 'lname': ' Fox'}, 'patient_numbers': ['041-718-3946', '530-198-8822', '401-300-6010'], 'weights': [107], 'height': 168, 'bp_readings': [{'Systolic': 121, 'Diastolic': 95, 'Rate': 61}, {'Systolic': 139, 'Diastolic': 70, 'Rate': 95}, {'Systolic': 113, 'Diastolic': 85, 'Rate': 72}, {'Systolic': 117, 'Diastolic': 79, 'Rate': 97}, {'Systolic': 135, 'Diastolic': 86, 'Rate': 76}, {'Systolic': 114, 'Diastolic': 75, 'Rate': 73}, {'Systolic': 125, 'Diastolic': 98, 'Rate': 63}]}
# {'_id': 41, 'office_num': [9], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Boone'}, 'patient_numbers': ['556-109-2812', '332-410-5217'], 'weights': [208, 112], 'height': 195, 'bp_readings': [{'Systolic': 122, 'Diastolic': 71, 'Rate': 97}, {'Systolic': 105, 'Diastolic': 84, 'Rate': 72}, {'Systolic': 150, 'Diastolic': 77, 'Rate': 102}, {'Systolic': 111, 'Diastolic': 73, 'Rate': 63}, {'Systolic': 112, 'Diastolic': 71, 'Rate': 107}, {'Systolic': 146, 'Diastolic': 73, 'Rate': 65}]}
# {'_id': 42, 'office_num': [5], 'patient_info': {'fname': 'Elizabeth', 'lname': ' Fox'}, 'patient_numbers': ['630-435-5579', '661-637-5291', '316-484-5567', '555-678-0524'], 'weights': [244, 380], 'height': 116, 'bp_readings': [{'Systolic': 145, 'Diastolic': 93, 'Rate': 69}, {'Systolic': 110, 'Diastolic': 84, 'Rate': 101}, {'Systolic': 140, 'Diastolic': 74, 'Rate': 68}, {'Systolic': 110, 'Diastolic': 72, 'Rate': 99}, {'Systolic': 116, 'Diastolic': 77, 'Rate': 82}, {'Systolic': 141, 'Diastolic': 80, 'Rate': 70}, {'Systolic': 117, 'Diastolic': 97, 'Rate': 90}, {'Systolic': 119, 'Diastolic': 72, 'Rate': 87}, {'Systolic': 109, 'Diastolic': 87, 'Rate': 82}, {'Systolic': 128, 'Diastolic': 99, 'Rate': 66}]}
# {'_id': 43, 'office_num': [6], 'patient_info': {'fname': 'Betty', 'lname': 'Carmichael'}, 'patient_numbers': ['800-355-8585', '512-604-9303', '459-635-0349'], 'weights': [190], 'height': 112, 'bp_readings': [{'Systolic': 114, 'Diastolic': 81, 'Rate': 92}, {'Systolic': 117, 'Diastolic': 74, 'Rate': 70}, {'Systolic': 114, 'Diastolic': 72, 'Rate': 79}, {'Systolic': 136, 'Diastolic': 86, 'Rate': 92}]}
# {'_id': 44, 'office_num': [8], 'patient_info': {'fname': 'Jordan', 'lname': 'Hale'}, 'patient_numbers': ['285-361-4332', '230-275-2051', '933-173-9529'], 'weights': [201], 'height': 140, 'bp_readings': [{'Systolic': 135, 'Diastolic': 71, 'Rate': 63}, {'Systolic': 123, 'Diastolic': 85, 'Rate': 95}, {'Systolic': 122, 'Diastolic': 74, 'Rate': 91}, {'Systolic': 104, 'Diastolic': 86, 'Rate': 80}, {'Systolic': 142, 'Diastolic': 93, 'Rate': 96}, {'Systolic': 142, 'Diastolic': 79, 'Rate': 98}, {'Systolic': 120, 'Diastolic': 98, 'Rate': 110}, {'Systolic': 136, 'Diastolic': 72, 'Rate': 90}, {'Systolic': 121, 'Diastolic': 83, 'Rate': 64}]}
# {'_id': 45, 'office_num': [2], 'patient_info': {'fname': 'Susan', 'lname': 'Madden'}, 'patient_numbers': ['253-544-4760', '424-016-6934'], 'weights': [379, 343, 384], 'height': 136, 'bp_readings': [{'Systolic': 143, 'Diastolic': 75, 'Rate': 80}, {'Systolic': 109, 'Diastolic': 81, 'Rate': 66}, {'Systolic': 125, 'Diastolic': 81, 'Rate': 93}, {'Systolic': 147, 'Diastolic': 88, 'Rate': 104}, {'Systolic': 112, 'Diastolic': 82, 'Rate': 88}, {'Systolic': 109, 'Diastolic': 96, 'Rate': 90}]}
# {'_id': 46, 'office_num': [1], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Granger'}, 'patient_numbers': ['108-879-7582', '976-068-8729'], 'weights': [281, 116, 278, 270, 314], 'height': 130, 'bp_readings': [{'Systolic': 119, 'Diastolic': 97, 'Rate': 65}, {'Systolic': 128, 'Diastolic': 94, 'Rate': 82}, {'Systolic': 112, 'Diastolic': 75, 'Rate': 68}, {'Systolic': 128, 'Diastolic': 99, 'Rate': 62}, {'Systolic': 123, 'Diastolic': 88, 'Rate': 81}, {'Systolic': 111, 'Diastolic': 88, 'Rate': 91}, {'Systolic': 130, 'Diastolic': 70, 'Rate': 96}, {'Systolic': 114, 'Diastolic': 98, 'Rate': 99}, {'Systolic': 103, 'Diastolic': 84, 'Rate': 101}, {'Systolic': 110, 'Diastolic': 86, 'Rate': 73}]}
# {'_id': 47, 'office_num': [8], 'patient_info': {'fname': 'Betty', 'lname': 'Madden'}, 'patient_numbers': ['225-229-8438', '677-884-2898', '493-420-5166'], 'weights': [181, 315, 320, 363, 316], 'height': 146, 'bp_readings': [{'Systolic': 103, 'Diastolic': 72, 'Rate': 106}, {'Systolic': 106, 'Diastolic': 73, 'Rate': 94}, {'Systolic': 124, 'Diastolic': 74, 'Rate': 88}, {'Systolic': 125, 'Diastolic': 75, 'Rate': 90}, {'Systolic': 128, 'Diastolic': 86, 'Rate': 97}]}
# {'_id': 48, 'office_num': [10], 'patient_info': {'fname': 'James', 'lname': 'Langston'}, 'patient_numbers': ['764-529-4208', '018-375-7516', '074-675-8126'], 'weights': [308, 334, 348, 166, 253], 'height': 118, 'bp_readings': [{'Systolic': 108, 'Diastolic': 89, 'Rate': 72}, {'Systolic': 114, 'Diastolic': 95, 'Rate': 73}, {'Systolic': 129, 'Diastolic': 90, 'Rate': 69}, {'Systolic': 106, 'Diastolic': 92, 'Rate': 66}, {'Systolic': 127, 'Diastolic': 71, 'Rate': 89}, {'Systolic': 109, 'Diastolic': 81, 'Rate': 95}, {'Systolic': 120, 'Diastolic': 78, 'Rate': 85}]}
# {'_id': 49, 'office_num': [7], 'patient_info': {'fname': 'Jack', 'lname': 'Boone'}, 'patient_numbers': ['496-542-1727', '271-818-5578', '595-897-5768'], 'weights': [175, 213], 'height': 168, 'bp_readings': [{'Systolic': 138, 'Diastolic': 99, 'Rate': 75}, {'Systolic': 103, 'Diastolic': 94, 'Rate': 80}, {'Systolic': 139, 'Diastolic': 94, 'Rate': 63}, {'Systolic': 121, 'Diastolic': 83, 'Rate': 61}, {'Systolic': 122, 'Diastolic': 81, 'Rate': 83}]}
# {'_id': 50, 'office_num': [4], 'patient_info': {'fname': 'Tom', 'lname': ' Fox'}, 'patient_numbers': ['566-206-5993', '319-563-4160'], 'weights': [137, 298, 168], 'height': 114, 'bp_readings': [{'Systolic': 150, 'Diastolic': 93, 'Rate': 71}, {'Systolic': 148, 'Diastolic': 80, 'Rate': 69}, {'Systolic': 124, 'Diastolic': 83, 'Rate': 80}, {'Systolic': 134, 'Diastolic': 97, 'Rate': 100}, {'Systolic': 144, 'Diastolic': 86, 'Rate': 77}, {'Systolic': 113, 'Diastolic': 76, 'Rate': 70}, {'Systolic': 110, 'Diastolic': 87, 'Rate': 70}, {'Systolic': 109, 'Diastolic': 73, 'Rate': 88}, {'Systolic': 137, 'Diastolic': 86, 'Rate': 68}, {'Systolic': 127, 'Diastolic': 74, 'Rate': 81}]}

# %% [markdown]
# ### Find a document based on a (first level) field value

# %%
query = { "_id": 1 } # search for any five start restaurants
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4)) # using json.dumps() to make the output more readable
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": "good patient" }
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": {"$regex": "ood" }} # https://en.wikipedia.org/wiki/Regular_expression
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Query values in an embedded array
# In our sample data, we have an embedded array of phone numbers. Here's how we can search an embedded array.

# %%
query = { "patient_numbers": {"$regex": '^177'}} # search for records that have this area code
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "bp_readings": {"Systolic" : 148 , "Diastolic": 84, "Rate": 78}} # in this style, you need all fields
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Querying embedded documents
#
# In our sample data, the readings field contains an array of embeded documents. Let's explore some examples showing how we can search an embedded document.

# %%
# in this style, you need all fields - so this one won't return anything
query = { "bp_readings": {"Systolic" : 148}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))

# %%
# If you want to query on one field, you can use the following approach
query = { "bp_readings.Systolic" : 148} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 15,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "185-788-0248",
#         "459-368-6274"
#     ],
#     "weights": [
#         258,
#         203,
#         222,
#         215,
#         105
#     ],
#     "height": 179,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 99,
#             "Rate": 87
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 77,
#             "Rate": 110
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 76,
#             "Rate": 64
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 70
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 84,
#             "Rate": 97
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 74,
#             "Rate": 98
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 84,
#             "Rate": 93
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 74,
#             "Rate": 109
#         }
#     ]
# }
# {
#     "_id": 50,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "566-206-5993",
#         "319-563-4160"
#     ],
#     "weights": [
#         137,
#         298,
#         168
#     ],
#     "height": 114,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 93,
#             "Rate": 71
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 80,
#             "Rate": 69
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 83,
#             "Rate": 80
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 97,
#             "Rate": 100
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 86,
#             "Rate": 77
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 76,
#             "Rate": 70
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 87,
#             "Rate": 70
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 73,
#             "Rate": 88
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 86,
#             "Rate": 68
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 74,
#             "Rate": 81
#         }
#     ]
# }

# %%
# we can also check for greater than, greater than equal, less than, less than equal
query = { "bp_readings.Systolic" : {"$gte" : 130}} # in this style, you need all fields - so this one won't return anything
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 2,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "497-869-0736",
#         "625-851-7812",
#         "865-707-0499"
#     ],
#     "weights": [
#         291,
#         177,
#         176,
#         347,
#         206
#     ],
#     "height": 101,
#     "bp_readings": [
#         {
#             "Systolic": 134,
#             "Diastolic": 99,
#             "Rate": 95
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 82,
#             "Rate": 92
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 97,
#             "Rate": 96
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 84,
#             "Rate": 77
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 87,
#             "Rate": 98
#         }
#     ]
# }
# {
#     "_id": 3,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "883-607-5983",
#         "867-565-0889"
#     ],
#     "weights": [
#         259,
#         324,
#         397,
#         104,
#         207
#     ],
#     "height": 181,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 88,
#             "Rate": 71
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 95,
#             "Rate": 95
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 71,
#             "Rate": 103
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 72,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 4,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "419-254-1224",
#         "824-475-7710"
#     ],
#     "weights": [
#         287,
#         265,
#         305
#     ],
#     "height": 124,
#     "bp_readings": [
#         {
#             "Systolic": 106,
#             "Diastolic": 78,
#             "Rate": 106
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 76,
#             "Rate": 98
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 96,
#             "Rate": 61
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 70,
#             "Rate": 85
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 71,
#             "Rate": 106
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 84,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 5,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "380-695-6042",
#         "304-114-4269",
#         "420-809-3972"
#     ],
#     "weights": [
#         350,
#         109,
#         283,
#         192,
#         267
#     ],
#     "height": 112,
#     "bp_readings": [
#         {
#             "Systolic": 136,
#             "Diastolic": 91,
#             "Rate": 87
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 76,
#             "Rate": 91
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 91,
#             "Rate": 84
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 86,
#             "Rate": 91
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 80,
#             "Rate": 99
#         }
#     ]
# }
# {
#     "_id": 6,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "592-563-4168",
#         "587-831-0122"
#     ],
#     "weights": [
#         365,
#         199
#     ],
#     "height": 134,
#     "bp_readings": [
#         {
#             "Systolic": 138,
#             "Diastolic": 86,
#             "Rate": 76
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 80,
#             "Rate": 81
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 79,
#             "Rate": 75
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 94,
#             "Rate": 105
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 74,
#             "Rate": 97
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 94,
#             "Rate": 66
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 71,
#             "Rate": 86
#         }
#     ]
# }
# {
#     "_id": 7,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "519-961-9839",
#         "145-498-1741"
#     ],
#     "weights": [
#         241
#     ],
#     "height": 101,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 83,
#             "Rate": 67
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 71,
#             "Rate": 72
#         }
#     ]
# }
# {
#     "_id": 8,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "723-216-6848",
#         "475-135-0004"
#     ],
#     "weights": [
#         253,
#         320,
#         290,
#         250,
#         294
#     ],
#     "height": 108,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 89,
#             "Rate": 89
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 78,
#             "Rate": 73
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 89,
#             "Rate": 109
#         }
#     ]
# }
# {
#     "_id": 9,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "343-351-4171",
#         "953-640-5259",
#         "435-189-9913",
#         "303-614-8110"
#     ],
#     "weights": [
#         238
#     ],
#     "height": 196,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 85,
#             "Rate": 69
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 86,
#             "Rate": 109
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 80,
#             "Rate": 64
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 91,
#             "Rate": 71
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 94,
#             "Rate": 69
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 96,
#             "Rate": 80
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 73,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 10,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "059-832-4682",
#         "034-176-8487",
#         "870-652-4706",
#         "900-592-9224"
#     ],
#     "weights": [
#         293,
#         378,
#         295
#     ],
#     "height": 122,
#     "bp_readings": [
#         {
#             "Systolic": 114,
#             "Diastolic": 85,
#             "Rate": 60
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 86,
#             "Rate": 80
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 98,
#             "Rate": 101
#         }
#     ]
# }
# {
#     "_id": 11,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "736-589-4301",
#         "852-834-4485",
#         "279-119-8962"
#     ],
#     "weights": [
#         218,
#         308
#     ],
#     "height": 127,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 91,
#             "Rate": 85
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 90,
#             "Rate": 82
#         }
#     ]
# }
# {
#     "_id": 12,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "081-414-1291",
#         "736-662-5729",
#         "731-698-6144",
#         "368-038-7900"
#     ],
#     "weights": [
#         214,
#         223,
#         195,
#         178,
#         235
#     ],
#     "height": 118,
#     "bp_readings": [
#         {
#             "Systolic": 112,
#             "Diastolic": 78,
#             "Rate": 79
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 94,
#             "Rate": 76
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 84,
#             "Rate": 110
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 87,
#             "Rate": 82
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 83,
#             "Rate": 67
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 76,
#             "Rate": 96
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 76,
#             "Rate": 78
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 98,
#             "Rate": 61
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 88,
#             "Rate": 107
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 87,
#             "Rate": 78
#         }
#     ]
# }
# {
#     "_id": 13,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "468-585-0177",
#         "548-659-7166",
#         "380-498-3798",
#         "642-798-3580"
#     ],
#     "weights": [
#         386,
#         308,
#         297,
#         262
#     ],
#     "height": 179,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 93,
#             "Rate": 75
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 90,
#             "Rate": 78
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 70,
#             "Rate": 86
#         }
#     ]
# }
# {
#     "_id": 14,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "190-546-8427",
#         "472-780-4819"
#     ],
#     "weights": [
#         125,
#         271,
#         124,
#         316
#     ],
#     "height": 102,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 72,
#             "Rate": 85
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 92,
#             "Rate": 77
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 79,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 15,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "185-788-0248",
#         "459-368-6274"
#     ],
#     "weights": [
#         258,
#         203,
#         222,
#         215,
#         105
#     ],
#     "height": 179,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 99,
#             "Rate": 87
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 77,
#             "Rate": 110
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 76,
#             "Rate": 64
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 70
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 84,
#             "Rate": 97
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 74,
#             "Rate": 98
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 84,
#             "Rate": 93
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 74,
#             "Rate": 109
#         }
#     ]
# }
# {
#     "_id": 16,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "313-411-3657",
#         "120-090-3078",
#         "975-419-2136"
#     ],
#     "weights": [
#         343,
#         320
#     ],
#     "height": 148,
#     "bp_readings": [
#         {
#             "Systolic": 114,
#             "Diastolic": 77,
#             "Rate": 78
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 87,
#             "Rate": 97
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 76,
#             "Rate": 88
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 78,
#             "Rate": 81
#         }
#     ]
# }
# {
#     "_id": 17,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "000-756-9436",
#         "220-062-8096"
#     ],
#     "weights": [
#         156,
#         130,
#         326
#     ],
#     "height": 183,
#     "bp_readings": [
#         {
#             "Systolic": 100,
#             "Diastolic": 71,
#             "Rate": 94
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 86,
#             "Rate": 68
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 99,
#             "Rate": 77
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 73,
#             "Rate": 87
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 76,
#             "Rate": 61
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 90,
#             "Rate": 68
#         }
#     ]
# }
# {
#     "_id": 18,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "544-330-9925",
#         "698-805-8683",
#         "861-491-4212"
#     ],
#     "weights": [
#         194
#     ],
#     "height": 154,
#     "bp_readings": [
#         {
#             "Systolic": 103,
#             "Diastolic": 90,
#             "Rate": 65
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 85,
#             "Rate": 92
#         }
#     ]
# }
# {
#     "_id": 19,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "807-267-0841",
#         "451-406-0452"
#     ],
#     "weights": [
#         284,
#         149,
#         245
#     ],
#     "height": 112,
#     "bp_readings": [
#         {
#             "Systolic": 115,
#             "Diastolic": 86,
#             "Rate": 95
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 80,
#             "Rate": 81
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 95,
#             "Rate": 85
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 85,
#             "Rate": 66
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 90,
#             "Rate": 88
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 87,
#             "Rate": 106
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 92,
#             "Rate": 93
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 70,
#             "Rate": 78
#         }
#     ]
# }
# {
#     "_id": 20,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "516-529-1048",
#         "564-554-5880",
#         "812-555-9174",
#         "775-619-0208"
#     ],
#     "weights": [
#         384,
#         218,
#         215,
#         383
#     ],
#     "height": 195,
#     "bp_readings": [
#         {
#             "Systolic": 123,
#             "Diastolic": 95,
#             "Rate": 101
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 82,
#             "Rate": 79
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 89,
#             "Rate": 81
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 86,
#             "Rate": 70
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 74,
#             "Rate": 76
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 77,
#             "Rate": 96
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 99,
#             "Rate": 67
#         }
#     ]
# }
# {
#     "_id": 21,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "184-134-1981",
#         "132-860-9574"
#     ],
#     "weights": [
#         192,
#         396
#     ],
#     "height": 163,
#     "bp_readings": [
#         {
#             "Systolic": 127,
#             "Diastolic": 84,
#             "Rate": 103
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 87,
#             "Rate": 72
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 93,
#             "Rate": 64
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 83,
#             "Rate": 72
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 93,
#             "Rate": 94
#         }
#     ]
# }
# {
#     "_id": 22,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "989-960-5703",
#         "408-148-5898",
#         "486-886-9947"
#     ],
#     "weights": [
#         157,
#         349,
#         317
#     ],
#     "height": 175,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 94,
#             "Rate": 70
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 90,
#             "Rate": 60
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 93,
#             "Rate": 102
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 71,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 23,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "106-474-5756",
#         "717-526-2024"
#     ],
#     "weights": [
#         155,
#         391,
#         237
#     ],
#     "height": 152,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 79,
#             "Rate": 107
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 92,
#             "Rate": 77
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 80,
#             "Rate": 109
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 76,
#             "Rate": 105
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 82,
#             "Rate": 105
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 72,
#             "Rate": 64
#         }
#     ]
# }
# {
#     "_id": 24,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "014-271-6201",
#         "690-838-6501",
#         "861-442-7031",
#         "617-487-6197"
#     ],
#     "weights": [
#         166
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 110,
#             "Diastolic": 86,
#             "Rate": 76
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 93,
#             "Rate": 94
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 97,
#             "Rate": 91
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 98,
#             "Rate": 94
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 95,
#             "Rate": 108
#         }
#     ]
# }
# {
#     "_id": 25,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "540-874-1384",
#         "436-224-3689",
#         "089-826-4474",
#         "473-759-7352"
#     ],
#     "weights": [
#         182,
#         387,
#         320,
#         363,
#         166
#     ],
#     "height": 107,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 86,
#             "Rate": 104
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 90,
#             "Rate": 108
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 80,
#             "Rate": 99
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 85,
#             "Rate": 81
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 74,
#             "Rate": 68
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 78,
#             "Rate": 74
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 90,
#             "Rate": 94
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 71,
#             "Rate": 96
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 91,
#             "Rate": 67
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 88,
#             "Rate": 72
#         }
#     ]
# }
# {
#     "_id": 26,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "493-134-5498",
#         "601-552-1429"
#     ],
#     "weights": [
#         267
#     ],
#     "height": 109,
#     "bp_readings": [
#         {
#             "Systolic": 146,
#             "Diastolic": 73,
#             "Rate": 79
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 77,
#             "Rate": 77
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 71,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 27,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "315-408-5152",
#         "946-199-8796",
#         "864-348-2098"
#     ],
#     "weights": [
#         179
#     ],
#     "height": 130,
#     "bp_readings": [
#         {
#             "Systolic": 127,
#             "Diastolic": 78,
#             "Rate": 94
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 78,
#             "Rate": 94
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 86,
#             "Rate": 76
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 74,
#             "Rate": 85
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 73,
#             "Rate": 107
#         }
#     ]
# }
# {
#     "_id": 28,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "888-909-4722",
#         "192-375-5422",
#         "676-192-4490"
#     ],
#     "weights": [
#         94,
#         157,
#         284,
#         377,
#         141
#     ],
#     "height": 158,
#     "bp_readings": [
#         {
#             "Systolic": 149,
#             "Diastolic": 83,
#             "Rate": 98
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 83,
#             "Rate": 77
#         }
#     ]
# }
# {
#     "_id": 29,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "017-000-1928",
#         "858-495-7393",
#         "185-210-5654"
#     ],
#     "weights": [
#         312
#     ],
#     "height": 153,
#     "bp_readings": [
#         {
#             "Systolic": 122,
#             "Diastolic": 79,
#             "Rate": 108
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 84,
#             "Rate": 104
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 90,
#             "Rate": 99
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 74,
#             "Rate": 63
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 91,
#             "Rate": 67
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 75,
#             "Rate": 94
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 90,
#             "Rate": 91
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 94,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 30,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "626-313-5537",
#         "757-367-6819"
#     ],
#     "weights": [
#         226,
#         154,
#         166,
#         96
#     ],
#     "height": 148,
#     "bp_readings": [
#         {
#             "Systolic": 106,
#             "Diastolic": 95,
#             "Rate": 61
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 72,
#             "Rate": 71
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 94,
#             "Rate": 84
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 86,
#             "Rate": 78
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 74,
#             "Rate": 93
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 78,
#             "Rate": 61
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 82,
#             "Rate": 100
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 93,
#             "Rate": 110
#         }
#     ]
# }
# {
#     "_id": 31,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "836-225-3188",
#         "226-908-3630"
#     ],
#     "weights": [
#         187,
#         348,
#         364,
#         129,
#         216
#     ],
#     "height": 150,
#     "bp_readings": [
#         {
#             "Systolic": 107,
#             "Diastolic": 88,
#             "Rate": 101
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 82,
#             "Rate": 65
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 73,
#             "Rate": 101
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 71,
#             "Rate": 93
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 94,
#             "Rate": 60
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 97,
#             "Rate": 79
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 78,
#             "Rate": 106
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 75,
#             "Rate": 98
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 87,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 32,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "682-663-7452",
#         "494-291-5524",
#         "445-649-7022",
#         "433-198-9386"
#     ],
#     "weights": [
#         385,
#         161
#     ],
#     "height": 170,
#     "bp_readings": [
#         {
#             "Systolic": 125,
#             "Diastolic": 92,
#             "Rate": 72
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 90,
#             "Rate": 64
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 95,
#             "Rate": 102
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 70,
#             "Rate": 107
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 82,
#             "Rate": 86
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 74,
#             "Rate": 97
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 74,
#             "Rate": 103
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 87,
#             "Rate": 64
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 97,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 33,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "234-257-8418",
#         "437-049-9195",
#         "749-005-2211"
#     ],
#     "weights": [
#         390,
#         215,
#         196,
#         348
#     ],
#     "height": 164,
#     "bp_readings": [
#         {
#             "Systolic": 107,
#             "Diastolic": 99,
#             "Rate": 105
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 96,
#             "Rate": 84
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 99,
#             "Rate": 93
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 96,
#             "Rate": 105
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 78,
#             "Rate": 106
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 92,
#             "Rate": 67
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 94,
#             "Rate": 96
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 91,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 34,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "883-646-6471",
#         "228-070-7368",
#         "531-106-7329",
#         "838-685-3359"
#     ],
#     "weights": [
#         264
#     ],
#     "height": 106,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 96,
#             "Rate": 99
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 98,
#             "Rate": 69
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 85,
#             "Rate": 62
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 86,
#             "Rate": 64
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 82,
#             "Rate": 65
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 95,
#             "Rate": 92
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 90,
#             "Rate": 79
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 78,
#             "Rate": 82
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 99,
#             "Rate": 63
#         }
#     ]
# }
# {
#     "_id": 36,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "346-849-9112",
#         "461-248-4331",
#         "470-843-8185",
#         "548-207-5005"
#     ],
#     "weights": [
#         173,
#         375,
#         110,
#         391
#     ],
#     "height": 189,
#     "bp_readings": [
#         {
#             "Systolic": 127,
#             "Diastolic": 75,
#             "Rate": 72
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 73,
#             "Rate": 97
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 88,
#             "Rate": 92
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 77
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 76,
#             "Rate": 110
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 81,
#             "Rate": 89
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 99,
#             "Rate": 99
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 81,
#             "Rate": 74
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 70,
#             "Rate": 60
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 71,
#             "Rate": 70
#         }
#     ]
# }
# {
#     "_id": 37,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "182-083-3743",
#         "785-561-3923"
#     ],
#     "weights": [
#         242,
#         387,
#         308,
#         332,
#         276
#     ],
#     "height": 102,
#     "bp_readings": [
#         {
#             "Systolic": 101,
#             "Diastolic": 99,
#             "Rate": 66
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 96
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 89,
#             "Rate": 87
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 88,
#             "Rate": 81
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 72,
#             "Rate": 101
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 95,
#             "Rate": 91
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 88,
#             "Rate": 102
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 86,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 38,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "849-698-4440",
#         "907-753-8737",
#         "526-601-5048"
#     ],
#     "weights": [
#         246
#     ],
#     "height": 148,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 80,
#             "Rate": 79
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 98,
#             "Rate": 110
#         }
#     ]
# }
# {
#     "_id": 39,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "112-469-5302",
#         "895-446-6871",
#         "363-909-3336"
#     ],
#     "weights": [
#         197,
#         167,
#         243,
#         274
#     ],
#     "height": 100,
#     "bp_readings": [
#         {
#             "Systolic": 128,
#             "Diastolic": 85,
#             "Rate": 70
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 74,
#             "Rate": 61
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 97,
#             "Rate": 92
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 80,
#             "Rate": 98
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 88,
#             "Rate": 101
#         }
#     ]
# }
# {
#     "_id": 40,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "041-718-3946",
#         "530-198-8822",
#         "401-300-6010"
#     ],
#     "weights": [
#         107
#     ],
#     "height": 168,
#     "bp_readings": [
#         {
#             "Systolic": 121,
#             "Diastolic": 95,
#             "Rate": 61
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 70,
#             "Rate": 95
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 85,
#             "Rate": 72
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 79,
#             "Rate": 97
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 86,
#             "Rate": 76
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 75,
#             "Rate": 73
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 98,
#             "Rate": 63
#         }
#     ]
# }
# {
#     "_id": 41,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "556-109-2812",
#         "332-410-5217"
#     ],
#     "weights": [
#         208,
#         112
#     ],
#     "height": 195,
#     "bp_readings": [
#         {
#             "Systolic": 122,
#             "Diastolic": 71,
#             "Rate": 97
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 84,
#             "Rate": 72
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 77,
#             "Rate": 102
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 73,
#             "Rate": 63
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 71,
#             "Rate": 107
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 73,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 42,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "630-435-5579",
#         "661-637-5291",
#         "316-484-5567",
#         "555-678-0524"
#     ],
#     "weights": [
#         244,
#         380
#     ],
#     "height": 116,
#     "bp_readings": [
#         {
#             "Systolic": 145,
#             "Diastolic": 93,
#             "Rate": 69
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 84,
#             "Rate": 101
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 74,
#             "Rate": 68
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 72,
#             "Rate": 99
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 77,
#             "Rate": 82
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 80,
#             "Rate": 70
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 97,
#             "Rate": 90
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 72,
#             "Rate": 87
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 87,
#             "Rate": 82
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 99,
#             "Rate": 66
#         }
#     ]
# }
# {
#     "_id": 43,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "800-355-8585",
#         "512-604-9303",
#         "459-635-0349"
#     ],
#     "weights": [
#         190
#     ],
#     "height": 112,
#     "bp_readings": [
#         {
#             "Systolic": 114,
#             "Diastolic": 81,
#             "Rate": 92
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 74,
#             "Rate": 70
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 72,
#             "Rate": 79
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 86,
#             "Rate": 92
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "285-361-4332",
#         "230-275-2051",
#         "933-173-9529"
#     ],
#     "weights": [
#         201
#     ],
#     "height": 140,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 71,
#             "Rate": 63
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 85,
#             "Rate": 95
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 74,
#             "Rate": 91
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 86,
#             "Rate": 80
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 93,
#             "Rate": 96
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 79,
#             "Rate": 98
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 98,
#             "Rate": 110
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 72,
#             "Rate": 90
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 83,
#             "Rate": 64
#         }
#     ]
# }
# {
#     "_id": 45,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "253-544-4760",
#         "424-016-6934"
#     ],
#     "weights": [
#         379,
#         343,
#         384
#     ],
#     "height": 136,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 75,
#             "Rate": 80
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 81,
#             "Rate": 66
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 81,
#             "Rate": 93
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 88,
#             "Rate": 104
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 82,
#             "Rate": 88
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 96,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 46,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "108-879-7582",
#         "976-068-8729"
#     ],
#     "weights": [
#         281,
#         116,
#         278,
#         270,
#         314
#     ],
#     "height": 130,
#     "bp_readings": [
#         {
#             "Systolic": 119,
#             "Diastolic": 97,
#             "Rate": 65
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 94,
#             "Rate": 82
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 75,
#             "Rate": 68
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 99,
#             "Rate": 62
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 88,
#             "Rate": 81
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 88,
#             "Rate": 91
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 70,
#             "Rate": 96
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 98,
#             "Rate": 99
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 84,
#             "Rate": 101
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 86,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 49,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "496-542-1727",
#         "271-818-5578",
#         "595-897-5768"
#     ],
#     "weights": [
#         175,
#         213
#     ],
#     "height": 168,
#     "bp_readings": [
#         {
#             "Systolic": 138,
#             "Diastolic": 99,
#             "Rate": 75
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 94,
#             "Rate": 80
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 94,
#             "Rate": 63
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 83,
#             "Rate": 61
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 81,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 50,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "566-206-5993",
#         "319-563-4160"
#     ],
#     "weights": [
#         137,
#         298,
#         168
#     ],
#     "height": 114,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 93,
#             "Rate": 71
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 80,
#             "Rate": 69
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 83,
#             "Rate": 80
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 97,
#             "Rate": 100
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 86,
#             "Rate": 77
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 76,
#             "Rate": 70
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 87,
#             "Rate": 70
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 73,
#             "Rate": 88
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 86,
#             "Rate": 68
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 74,
#             "Rate": 81
#         }
#     ]
# }

# %% [markdown]
# Another approach is to use \$elemMatch. This will conduct an element wise match of the fields in an array of embedded documents.

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : 104}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 3,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "883-607-5983",
#         "867-565-0889"
#     ],
#     "weights": [
#         259,
#         324,
#         397,
#         104,
#         207
#     ],
#     "height": 181,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 88,
#             "Rate": 71
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 95,
#             "Rate": 95
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 71,
#             "Rate": 103
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 72,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "285-361-4332",
#         "230-275-2051",
#         "933-173-9529"
#     ],
#     "weights": [
#         201
#     ],
#     "height": 140,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 71,
#             "Rate": 63
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 85,
#             "Rate": 95
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 74,
#             "Rate": 91
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 86,
#             "Rate": 80
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 93,
#             "Rate": 96
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 79,
#             "Rate": 98
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 98,
#             "Rate": 110
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 72,
#             "Rate": 90
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 83,
#             "Rate": 64
#         }
#     ]
# }

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : {'$gte': 150}}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 7,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "519-961-9839",
#         "145-498-1741"
#     ],
#     "weights": [
#         241
#     ],
#     "height": 101,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 83,
#             "Rate": 67
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 71,
#             "Rate": 72
#         }
#     ]
# }
# {
#     "_id": 8,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "723-216-6848",
#         "475-135-0004"
#     ],
#     "weights": [
#         253,
#         320,
#         290,
#         250,
#         294
#     ],
#     "height": 108,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 89,
#             "Rate": 89
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 78,
#             "Rate": 73
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 89,
#             "Rate": 109
#         }
#     ]
# }
# {
#     "_id": 9,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "343-351-4171",
#         "953-640-5259",
#         "435-189-9913",
#         "303-614-8110"
#     ],
#     "weights": [
#         238
#     ],
#     "height": 196,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 85,
#             "Rate": 69
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 86,
#             "Rate": 109
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 80,
#             "Rate": 64
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 91,
#             "Rate": 71
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 94,
#             "Rate": 69
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 96,
#             "Rate": 80
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 73,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 41,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "556-109-2812",
#         "332-410-5217"
#     ],
#     "weights": [
#         208,
#         112
#     ],
#     "height": 195,
#     "bp_readings": [
#         {
#             "Systolic": 122,
#             "Diastolic": 71,
#             "Rate": 97
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 84,
#             "Rate": 72
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 77,
#             "Rate": 102
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 73,
#             "Rate": 63
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 71,
#             "Rate": 107
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 73,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 50,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "566-206-5993",
#         "319-563-4160"
#     ],
#     "weights": [
#         137,
#         298,
#         168
#     ],
#     "height": 114,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 93,
#             "Rate": 71
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 80,
#             "Rate": 69
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 83,
#             "Rate": 80
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 97,
#             "Rate": 100
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 86,
#             "Rate": 77
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 76,
#             "Rate": 70
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 87,
#             "Rate": 70
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 73,
#             "Rate": 88
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 86,
#             "Rate": 68
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 74,
#             "Rate": 81
#         }
#     ]
# }

# %%
client.close()

# %% [markdown]
# ## Step 3: Review other possibly querries
#
# There are many ways we could use MongoDB to query the data. See here for more examples https://docs.mongodb.com/manual/tutorial/query-documents/. I'd also encourate you to experiment and try queries through the MongoDB online interface.

# %% [markdown]
# ## Use of Indices
#
# Indices can be used to improve the performance of queries. See [here](https://docs.mongodb.com/manual/indexes/) for more information on indices.
